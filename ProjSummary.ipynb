# %% [markdown]
# # Overview
#
# ## Initial EDA
# - Source Lending Club data from kaggle
# - Quick head check.
#     - Reveals some columns may have many missing values.
#     - Summarize miss % by column with isnull() to check.
# - dropna() columns with 80% missing
# - Check dataframe rows / cols with df shape
# - Check loan status (target var) counts by cat with value_counts() and plot
# - Subset data to closed loans (paid and chargeoff)
# - Calc chargeoff rate
#
# ## Cleaning
# - Check out loan amount distribution.
